# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,3,figsize=(24,5))

fields = 169

cats = ['FC\np<0.05', 'FC\np<0.01', 'VAE Z\np<0.05', 'VAE Z\np<0.01', 'DemoVAE Z\np<0.05', 'DemoVAE Z\np<0.01']
rest_counts = [70, 55, 97, 88, 5, 1]
nback_counts = [91, 76, 102, 88, 13, 4]
emoid_counts = [88, 70, 91, 76, 13, 1] # 169 total fields
# emoid_counts = [168] # 895 total fields
bar_colors = ['tab:blue', 'tab:blue', 'tab:red', 'tab:red', 'tab:orange', 'tab:orange']

p = ax[0].bar(cats, rest_counts, color=bar_colors)
ax[0].bar_label(p, label_type='edge')
ax[0].set_title('Resting State Task')
ax[0].set_ylim([0,110])

p = ax[1].bar(cats, nback_counts, color=bar_colors)
ax[1].bar_label(p, label_type='edge')
ax[1].set_title('Working Memory Task')
ax[1].set_ylim([0,110])

p = ax[2].bar(cats, emoid_counts, color=bar_colors)
ax[2].bar_label(p, label_type='edge')
ax[2].set_title('Emotion Identification Task')
ax[2].set_ylim([0,110])

fig.subplots_adjust(top=0.85)

fig.suptitle('Significant Correlations Between Tasks/Questionnaire/Demographic Fields\nand FC/DemoVAE Latents in PNC Dataset')
fig.show()

fig.savefig('/home/anton/Documents/Tulane/Research/Work/CL-VAE/pnc-fc-z-corr2.pdf')
# Out:
# /tmp/ipykernel_289937/2650979941.py:31: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,1,figsize=(8,4))

fields = 30

cats = ['FC\np<0.05', 'FC\np<0.01', 'VAE Z\np<0.05', 'VAE Z\np<0.01', 'DemoVAE Z\np<0.05', 'DemoVAE Z\np<0.01']
counts = [17, 8, 16, 5, 5, 3]
bar_colors = ['tab:blue', 'tab:blue', 'tab:red', 'tab:red', 'tab:orange', 'tab:orange']

p = ax.bar(cats, counts, color=bar_colors)
ax.bar_label(p, label_type='edge')
ax.set_title('Significant Correlations Between Questionnaire/Demographic Fields\nand FC/DemoVAE Latents in BSNIP Dataset')
ax.set_ylim([0,30])

fig.show()
fig.savefig('/home/anton/Documents/Tulane/Research/Work/CL-VAE/bsnip-fc-z-corr2.pdf')
# Out:
# /tmp/ipykernel_289937/1966612308.py:16: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,1,figsize=(8,4))

fields = 30

cats = ['SNPs\np<0.05', 'SNPs\np<0.01', 'VAE Z\np<0.05', 'VAE Z\np<0.01', 'DemoVAE Z\np<0.05', 'DemoVAE Z\np<0.01']
counts = [102, 75, 74, 65, 14, 2]
bar_colors = ['tab:blue', 'tab:blue', 'tab:red', 'tab:red', 'tab:orange', 'tab:orange']

p = ax.bar(cats, counts, color=bar_colors)
ax.bar_label(p, label_type='edge')
ax.set_title('Significant Correlations Between Tasks/Questionnaire/Demographic Fields\nand SNPs/DemoVAE Latents in PNC Dataset')
ax.set_ylim([0,110])

fig.show()
fig.savefig('/home/anton/Documents/Tulane/Research/Work/CL-VAE/pnc-snps-z-corr.pdf')
